# %%
import numpy as np
import pandas as pd
import cufflinks as cf
import plotly
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:111: UserWarning:
#
# The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.

# %%
stmf = pd.read_csv("stmf.csv.gz")
stmf
# Out:
#        country_code          cname iso2      continent iso3  year  week sex  \
# 0               AUS      Australia   AU        Oceania  AUS  2015     1   m
# 1               AUS      Australia   AU        Oceania  AUS  2015     1   m
# 2               AUS      Australia   AU        Oceania  AUS  2015     1   m
# 3               AUS      Australia   AU        Oceania  AUS  2015     1   m
# 4               AUS      Australia   AU        Oceania  AUS  2015     1   m
# ...             ...            ...  ...            ...  ...   ...   ...  ..
# 507670          USA  United States   US  North America  USA  2021     5   b
# 507671          USA  United States   US  North America  USA  2021     5   b
# 507672          USA  United States   US  North America  USA  2021     5   b
# 507673          USA  United States   US  North America  USA  2021     5   b
# 507674          USA  United States   US  North America  USA  2021     5   b
#
# ...

# %%
uspop = pd.read_csv("uspop.csv.gz")
uspop
# Out:
#        state state_abbr  statefips region_name       division_name  sex_id  \
# 0    Alabama         AL          1       South  East South Central  female
# 1    Alabama         AL          1       South  East South Central  female
# 2    Alabama         AL          1       South  East South Central  female
# 3    Alabama         AL          1       South  East South Central    male
# 4    Alabama         AL          1       South  East South Central    male
# ..       ...        ...        ...         ...                 ...     ...
# 454  Wyoming         WY         56        West            Mountain    male
# 455  Wyoming         WY         56        West            Mountain    male
# 456  Wyoming         WY         56        West            Mountain  totsex
# 457  Wyoming         WY         56        West            Mountain  totsex
# 458  Wyoming         WY         56        West            Mountain  totsex
#
# ...

# %%
apple_mobility = pd.read_csv("apple_mobility.csv.gz")
apple_mobility
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3251: DtypeWarning:
#
# Columns (3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#                geo_type       region transportation_type alternative_name  \
# 0        country/region      Albania             driving              NaN
# 1        country/region      Albania             driving              NaN
# 2        country/region      Albania             driving              NaN
# 3        country/region      Albania             driving              NaN
# 4        country/region      Albania             driving              NaN
# ...                 ...          ...                 ...              ...
# 2045271          county  Yuma County             walking              NaN
# 2045272          county  Yuma County             walking              NaN
# 2045273          county  Yuma County             walking              NaN
# ...

# %%
cdc_catchments = pd.read_csv("cdc_catchments.csv.gz")
cdc_catchments
# Out:
#          name            area
# 0   COVID-NET  Entire Network
# 1         EIP      California
# 2         EIP        Colorado
# 3         EIP     Connecticut
# 4         EIP  Entire Network
# 5         EIP         Georgia
# 6         EIP        Maryland
# 7         EIP       Minnesota
# 8         EIP      New Mexico
# 9         EIP        New York
# 10        EIP          Oregon
# 11        EIP       Tennessee
# 12       IHSP  Entire Network
# 13       IHSP            Iowa
# 14       IHSP        Michigan
# 15       IHSP            Ohio
# 16       IHSP            Utah

# %%
cdc_deaths_by_age = pd.read_csv("cdc_deaths_by_age.csv.gz")
cdc_deaths_by_age
# Out:
#     data_as_of   age_group  start_week    end_week  covid_deaths  \
# 0   2020-04-30    All ages  2020-02-01  2020-04-25         34521
# 1   2020-04-30  Under 1 yr  2020-02-01  2020-04-25             4
# 2   2020-04-30      1–4 yr  2020-02-01  2020-04-25             2
# 3   2020-04-30     5–14 yr  2020-02-01  2020-04-25             3
# 11  2020-04-30  2020-04-18  2020-04-18          9333         52642
# 12  2020-04-30  2020-04-25  2020-04-25          2167         24387
#
# ...

# %%
countries = pd.read_csv("countries.csv.gz")
countries
# Out:
#                  cname iso3 iso2 continent
# 0          Afghanistan  AFG   AF      Asia
# 1              Algeria  DZA   DZ    Africa
# 2              Armenia  ARM   AM      Asia
# 3            Australia  AUS   AU   Oceania
# 4              Austria  AUT   AT    Europe
# ..                 ...  ...  ...       ...
# 208            Lesotho  LSO   LS    Africa
# 209    Solomon Islands  SLB   SB   Oceania
# 210  Wallis and Futuna  WLF   WF   Oceania
# 211   Marshall Islands  MHL   MH   Oceania
# 212            Vanuatu  VUT   VU   Oceania
#
# [213 rows x 4 columns]

# %%
covnat_daily = pd.read_csv("covnat_daily.csv.gz")
covnat_daily
# Out:
#              date              cname iso3  cases  deaths         pop  \
# 0      2019-12-31        Afghanistan  AFG      0       0  38041757.0
# 1      2019-12-31            Algeria  DZA      0       0  43053054.0
# 2      2019-12-31            Armenia  ARM      0       0   2957728.0
# 3      2019-12-31          Australia  AUS      0       0  25203200.0
# 4      2019-12-31            Austria  AUT      0       0   8858775.0
# ...           ...                ...  ...    ...     ...         ...
# 61831  2020-12-14  Wallis and Futuna  WLF      0       0         NaN
# 61832  2020-12-14     Western Sahara  ESH      0       0    582458.0
# 61833  2020-12-14              Yemen  YEM      0       0  29161922.0
# 61834  2020-12-14             Zambia  ZMB     57       1  17861034.0
# 61835  2020-12-14           Zimbabwe  ZWE     27       0  14645473.0
#
#        cu_cases  cu_deaths
# 0             0          0
# 1             0          0
# 2             0          0
# ...

# %%
covus_ethnicity = pd.read_csv("covus_ethnicity.csv.gz")
covus_ethnicity
# Out:
#              date state         group     cases  deaths   hosp  tests
# 0      2021-03-07    AK      Hispanic    3197.0    13.0   66.0    NaN
# 1      2021-03-07    AK  Non-Hispanic   29625.0   280.0  939.0    NaN
# 2      2021-03-07    AK       Unknown   26510.0    12.0  288.0    NaN
# 3      2021-03-07    AL      Hispanic   12312.0   137.0    NaN    NaN
# 4      2021-03-07    AL  Non-Hispanic  167064.0  6083.0    NaN    NaN
# ...           ...   ...           ...       ...     ...    ...    ...
# 15955  2020-04-12    WV  Non-Hispanic       NaN     NaN    NaN    NaN
# 15956  2020-04-12    WV       Unknown       NaN     NaN    NaN    NaN
# 15957  2020-04-12    WY      Hispanic       NaN     NaN    NaN    NaN
# 15958  2020-04-12    WY  Non-Hispanic       NaN     NaN    NaN    NaN
# 15959  2020-04-12    WY       Unknown       NaN     NaN    NaN    NaN
#
# [15960 rows x 7 columns]

# %%
nchs_sas = pd.read_csv("nchs_sas.csv.gz")
nchs_sas
# Out:
#        data_as_of  start_date    end_date     group  year month  \
# 0      2021-03-24  01/01/2020  03/20/2021  By Total   NaN   NaN
# 1      2021-03-24  01/01/2020  03/20/2021  By Total   NaN   NaN
# 2      2021-03-24  01/01/2020  03/20/2021  By Total   NaN   NaN
# 3      2021-03-24  01/01/2020  03/20/2021  By Total   NaN   NaN
# 4      2021-03-24  01/01/2020  03/20/2021  By Total   NaN   NaN
# ...           ...         ...         ...       ...   ...   ...
# 49567  2021-03-24  03/01/2021  03/20/2021  By Month   NaN   NaN
# 49568  2021-03-24  03/01/2021  03/20/2021  By Month   NaN   NaN
# 49569  2021-03-24  03/01/2021  03/20/2021  By Month   NaN   NaN
# 49570  2021-03-24  03/01/2021  03/20/2021  By Month   NaN   NaN
# 49571  2021-03-24  03/01/2021  03/20/2021  By Month   NaN   NaN
#
#                state        sex          age_group  covid_19_deaths  \
# 0      United States  All Sexes           All ages         526028.0
# ...

# %%
nchs_wdc = pd.read_csv("nchs_wdc.csv.gz")
nchs_wdc
# Out:
#        jurisdiction  year  week week_ending_date  \
# 0           Alabama  2014     1       2014-01-04
# 1           Alabama  2014     1       2014-01-04
# 2           Alabama  2014     1       2014-01-04
# 3           Alabama  2014     1       2014-01-04
# 4           Alabama  2014     1       2014-01-04
# ...             ...   ...   ...              ...
# 270751      Wyoming  2021    10       2021-03-13
# 270752      Wyoming  2021    10       2021-03-13
# 270753      Wyoming  2021    10       2021-03-13
# 270754      Wyoming  2021    10       2021-03-13
# 270755      Wyoming  2021    10       2021-03-13
#
#                                            cause_detailed       n  \
# 0                                               All Cause  1057.0
# 1                                 Alzheimer disease (G30)    38.0
# 2                      Cerebrovascular diseases (I60-I69)    51.0
# 3            Chronic lower respiratory diseases (J40-J47)    66.0
# ...

# %%
nchs_wss = pd.read_csv("nchs_wss.csv.gz")
nchs_wss
# Out:
#      data_as_of  start_date    end_date          state  \
# 0    2021-03-24  01/01/2020  03/20/2021  United States
# 1    2021-03-24  01/01/2020  03/20/2021  United States
# 2    2021-03-24  01/01/2020  03/20/2021  United States
# 3    2021-03-24  01/01/2020  03/20/2021  United States
# 4    2021-03-24  01/01/2020  03/20/2021  United States
# ..          ...         ...         ...            ...
# 366  2021-03-24  01/01/2020  03/20/2021        Wyoming
# 367  2021-03-24  01/01/2020  03/20/2021        Wyoming
# 368  2021-03-24  01/01/2020  03/20/2021        Wyoming
# 369  2021-03-24  01/01/2020  03/20/2021        Wyoming
# 370  2021-03-24  01/01/2020  03/20/2021        Wyoming
#
#                                                  group    deaths  dist_pct  \
# 0                                   Non-Hispanic White  320437.0      60.9
# 1               Non-Hispanic Black or African American   76608.0      14.6
# 2        Non-Hispanic American Indian or Alaska Native    6060.0       1.2
# ...

# %%
nssp_covid_er_nat = pd.read_csv("nssp_covid_er_nat.csv.gz")
nssp_covid_er_nat
# Out:
#     week  num_fac  total_ed_visits  visits  pct_visits visit_type    region  \
# 0     40     3255          2146776   19503       0.009        ili  National
# 1     41     3249          2106999   20457       0.010        ili  National
# 2     42     3256          2101358   22515       0.011        ili  National
# 3     43     3254          2122427   23776       0.011        ili  National
# 4     44     3295          2087335   25466       0.012        ili  National
# 5     45     3315          2137854   29948       0.014        ili  National
# 6     46     3328          2122363   32425       0.015        ili  National
# 7     47     3334          2209698   36073       0.016        ili  National
# 8     48     3337          2097933   39613       0.019        ili  National
# 9     49     3336          2224300   37569       0.017        ili  National
# 10    50     3342          2240477   42485       0.019        ili  National
# ...

# %%
nssp_covid_er_reg = pd.read_csv("nssp_covid_er_reg.csv.gz")
nssp_covid_er_reg
# Out:
#      week  num_fac  total_ed_visits  visits  pct_visits visit_type     region  \
# 0      41      202           130377     814       0.006        ili   Region 1
# 1      42      202           132385     912       0.007        ili   Region 1
# 2      43      202           131866     883       0.007        ili   Region 1
# 3      44      203           128256     888       0.007        ili   Region 1
# 4      45      203           127466     979       0.008        ili   Region 1
# ..    ...      ...              ...     ...         ...        ...        ...
# 533    10      192            96177    2392       0.025        cli  Region 10
# 534    11      191            91706    3517       0.038        cli  Region 10
# 535    12      191            76249    3935       0.052        cli  Region 10
# 536    13      192            62257    2700       0.043        cli  Region 10
# 537    14      189            55508    1714       0.031        cli  Region 10
#
#                     source  year
# ...

# %%
nytcovcounty = pd.read_csv("nytcovcounty.csv.gz")
nytcovcounty
# Out:
#                date      county       state     fips  cases  deaths
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...             ...         ...         ...      ...    ...     ...
# 1150885  2021-03-23  Sweetwater     Wyoming  56037.0   3951    36.0
# 1150886  2021-03-23       Teton     Wyoming  56039.0   3532     9.0
# 1150887  2021-03-23       Uinta     Wyoming  56041.0   2111    12.0
# 1150888  2021-03-23    Washakie     Wyoming  56043.0    888    26.0
# 1150889  2021-03-23      Weston     Wyoming  56045.0    632     5.0
#
# [1150890 rows x 6 columns]

# %%
nytcovstate = pd.read_csv("nytcovstate.csv.gz")
nytcovstate
# Out:
#              date          state  fips   cases  deaths
# 0      2020-01-21     Washington    53       1       0
# 1      2020-01-22     Washington    53       1       0
# 2      2020-01-23     Washington    53       1       0
# 3      2020-01-24       Illinois    17       1       0
# 4      2020-01-24     Washington    53       1       0
# ...           ...            ...   ...     ...     ...
# 21239  2021-03-23       Virginia    51  607234   10137
# 21240  2021-03-23     Washington    53  359290    5249
# 21241  2021-03-23  West Virginia    54  138429    2613
# 21242  2021-03-23      Wisconsin    55  630040    7241
# 21243  2021-03-23        Wyoming    56   55799     695
#
# [21244 rows x 5 columns]

# %%
nytcovus = pd.read_csv("nytcovus.csv.gz")
nytcovus
# Out:
#            date     cases  deaths
# 0    2020-01-21         1       0
# 1    2020-01-22         1       0
# 2    2020-01-23         1       0
# 3    2020-01-24         2       0
# 4    2020-01-25         3       0
# ..          ...       ...     ...
# 423  2021-03-19  29754124  540720
# 424  2021-03-20  29808755  541493
# 425  2021-03-21  29842991  541937
# 426  2021-03-22  29897649  542587
# 427  2021-03-23  29957431  543479
#
# [428 rows x 3 columns]

# %%
nytexcess = pd.read_csv("nytexcess.csv.gz")
nytexcess
# Out:
#             country placename frequency  start_date    end_date  \
# 0           Austria       NaN    weekly  2020-01-06  2020-01-12
# 1           Austria       NaN    weekly  2020-01-13  2020-01-19
# 2           Austria       NaN    weekly  2020-01-20  2020-01-26
# 3           Austria       NaN    weekly  2020-01-27  2020-02-02
# 4           Austria       NaN    weekly  2020-02-03  2020-02-09
# ...             ...       ...       ...         ...         ...
# 7253  United States       NaN    weekly         NaN         NaN
# 7254  United States       NaN    weekly         NaN         NaN
# 7255  United States       NaN    weekly         NaN         NaN
# 7256  United States       NaN    weekly         NaN         NaN
# 7257  United States       NaN    weekly         NaN         NaN
#
#                    year  month  week  deaths  expected_deaths  excess_deaths  \
# 0                  2020      1   2.0    1702           1806.0         -104.0
# ...
